# %%
import pandas as pd
import numpy as np 
# %matplotlib inline

# %%
df = pd.read_csv('creditCardFraud_28011960_120210.csv')

# %%
df
# Out:
#       LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0         20000    2          2         1   24      2      2     -1     -1
# 1        120000    2          2         2   26     -1      2      0      0
# 2         90000    2          2         2   34      0      0      0      0
# 3         50000    2          2         1   37      0      0      0      0
# 4         50000    1          2         1   57     -1      0     -1      0
# ...         ...  ...        ...       ...  ...    ...    ...    ...    ...
# 996      140000    1          1         1   45      0      0      0      0
# 997      360000    1          1         1   38      1     -2     -2     -2
# 998       50000    2          2         2   23     -1     -1     -1      0
# 999      120000    1          2         2   25      2      2      0      0
# 1000     100000    1          2         1   29      0      0      0      0
#
# ...

# %%
df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...          0          0          0         0       689         0
# 1      0  ...       3272       3455       3261         0      1000      1000
# 2      0  ...      14331      14948      15549      1518      1500      1000
# 3      0  ...      28314      28959      29547      2000      2019      1200
# 4      0  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LIMIT_BAL                   1001 non-null   int64
#  1   SEX                         1001 non-null   int64
#  2   EDUCATION                   1001 non-null   int64
#  3   MARRIAGE                    1001 non-null   int64
#  4   AGE                         1001 non-null   int64
#  5   PAY_0                       1001 non-null   int64
#  6   PAY_2                       1001 non-null   int64
#  7   PAY_3                       1001 non-null   int64
#  8   PAY_4                       1001 non-null   int64
#  9   PAY_5                       1001 non-null   int64
#  10  PAY_6                       1001 non-null   int64
#  11  BILL_AMT1                   1001 non-null   int64
#  12  BILL_AMT2                   1001 non-null   int64
# ...

# %%
df.describe()
# Out:
#            LIMIT_BAL          SEX    EDUCATION     MARRIAGE          AGE  \
# count    1001.000000  1001.000000  1001.000000  1001.000000  1001.000000
# mean   167012.987013     1.590410     1.776224     1.604396    34.932068
# std    130584.718980     0.492004     0.749583     0.532298     9.225475
# min     10000.000000     1.000000     1.000000     0.000000    21.000000
# 25%     50000.000000     1.000000     1.000000     1.000000    28.000000
# 50%    140000.000000     2.000000     2.000000     2.000000    33.000000
# 75%    240000.000000     2.000000     2.000000     2.000000    41.000000
# max    700000.000000     2.000000     6.000000     3.000000    75.000000
#
#              PAY_0        PAY_2        PAY_3        PAY_4        PAY_5  ...  \
# count  1001.000000  1001.000000  1001.000000  1001.000000  1001.000000  ...
# mean     -0.001998    -0.152847    -0.160839    -0.279720    -0.280719  ...
# std       1.173029     1.229477     1.259804     1.182234     1.168810  ...
# ...

# %%
df.describe().T
# Out:
#                              count           mean            std       min  \
# LIMIT_BAL                   1001.0  167012.987013  130584.718980   10000.0
# SEX                         1001.0       1.590410       0.492004       1.0
# EDUCATION                   1001.0       1.776224       0.749583       1.0
# MARRIAGE                    1001.0       1.604396       0.532298       0.0
# AGE                         1001.0      34.932068       9.225475      21.0
# PAY_0                       1001.0      -0.001998       1.173029      -2.0
# PAY_2                       1001.0      -0.152847       1.229477      -2.0
# PAY_3                       1001.0      -0.160839       1.259804      -2.0
# PAY_4                       1001.0      -0.279720       1.182234      -2.0
# PAY_5                       1001.0      -0.280719       1.168810      -2.0
# PAY_6                       1001.0      -0.309690       1.204158      -2.0
# ...

# %%
# !pip install pandas-profiling

# %%
from pandas_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 from pandas_profiling import ProfileReport
#
# File ~\anaconda3\Lib\site-packages\pandas_profiling\__init__.py:6
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# File ~\anaconda3\Lib\site-packages\pandas_profiling\controller\pandas_decorator.py:4
#       1 """This file add the decorator on the DataFrame object."""
#       2 from pandas import DataFrame
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       7 def profile_report(df: DataFrame, **kwargs) -> ProfileReport:
#       8     """Profile a DataFrame.
#       9
# ...

# %%
df.isnull().sum()
# Out:
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.skew()
# Out:
# LIMIT_BAL                      1.017606
# SEX                           -0.368251
# EDUCATION                      0.876501
# MARRIAGE                      -0.104653
# AGE                            0.818122
# PAY_0                          1.512392
# PAY_2                          1.202142
# PAY_3                          1.231289
# PAY_4                          1.220549
# PAY_5                          1.052768
# PAY_6                          1.059881
# BILL_AMT1                      2.673869
# BILL_AMT2                      2.780194
# BILL_AMT3                      2.901528
# BILL_AMT4                      3.584781
# BILL_AMT5                      3.115105
# BILL_AMT6                      2.637191
# PAY_AMT1                       7.751935
# PAY_AMT2                      10.752543
# PAY_AMT3                       6.904009
# PAY_AMT4                       7.455487
# PAY_AMT5                       7.034855
# PAY_AMT6                      15.242300
# ...

# %%
x = df.iloc[:,:-1]

# %%
x
# Out:
#       LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0         20000    2          2         1   24      2      2     -1     -1
# 1        120000    2          2         2   26     -1      2      0      0
# 2         90000    2          2         2   34      0      0      0      0
# 3         50000    2          2         1   37      0      0      0      0
# 4         50000    1          2         1   57     -1      0     -1      0
# ...         ...  ...        ...       ...  ...    ...    ...    ...    ...
# 996      140000    1          1         1   45      0      0      0      0
# 997      360000    1          1         1   38      1     -2     -2     -2
# 998       50000    2          2         2   23     -1     -1     -1      0
# 999      120000    1          2         2   25      2      2      0      0
# 1000     100000    1          2         1   29      0      0      0      0
#
# ...

# %%
y = df.iloc[:,-1]

# %%
y
# Out:
# 0       1
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 996     0
# 997     1
# 998     1
# 999     0
# 1000    0
# Name: default payment next month, Length: 1001, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.pairplot(df)
plt.show()

# %%
sns.heatmap(df.corr(),annot = True)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.30,random_state = 42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
train_scale = scaler.fit_transform(x_train)

# %%
test_scale = scaler.transform(x_test)

# %%
scaled_train_df = pd.DataFrame(train_scale, columns = x_train.columns,index = x_train.index)

# %%
scaled_test_df = pd.DataFrame(test_scale, columns = x_test.columns, index = x_test.index)

# %%
scaled_train_df
# Out:
#      LIMIT_BAL       SEX  EDUCATION  MARRIAGE       AGE     PAY_0     PAY_2  \
# 440  -0.907252 -1.192537   0.253668  0.720533 -1.317897 -0.860208 -0.701427
# 482  -0.750675  0.838548   0.253668  0.720533 -0.778091  0.000000  0.103489
# 422   0.501941  0.838548   0.253668  0.720533  0.301520 -0.860208 -0.701427
# 852  -0.907252 -1.192537  -1.033053 -1.140623  0.193559  0.000000  0.103489
# 950  -1.063829 -1.192537  -1.033053 -1.140623 -0.886052 -0.860208  0.103489
# ..         ...       ...        ...       ...       ...       ...       ...
# 106  -0.672386  0.838548   0.253668 -1.140623  0.085598 -0.860208 -0.701427
# 270  -0.515809 -1.192537   1.540389  0.720533 -0.346247  0.000000  0.103489
# 860  -0.907252 -1.192537  -1.033053  0.720533 -0.994013 -1.720416 -1.506344
# 435   0.815095  0.838548   0.253668 -1.140623 -0.346247  0.860208  1.713323
# 102   2.459153 -1.192537  -1.033053 -1.140623  3.000548  0.000000  0.103489
#
# ...

# %%
from sklearn.naive_bayes import GaussianNB

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_nb = GaussianNB()

# %% [markdown]
# model_rf = RandomForestClassifier()

# %%
model_rf = RandomForestClassifier()

# %%
model_nb.fit(scaled_train_df, y_train)
# Out:
# GaussianNB()

# %%
model_rf.fit(scaled_train_df, y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score

# %%
y_pred_nb = model_nb.predict(scaled_test_df)

# %%
print(accuracy_score(y_pred_nb,y_test))
# Out:
# 0.36212624584717606

# %%
y_pred_rf = model_rf.predict(scaled_test_df)

# %%
print(accuracy_score(y_pred_rf,y_test))
# Out:
# 0.813953488372093

# %%
## Hyperparameter Tunning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'var_smoothing':[0.1,0.01,0.5,0.005,0.001,1e-6,1e-8,1e-10,1e-11]}

# %%
grid = GridSearchCV(estimator=model_nb,param_grid = param_grid, cv = 5 , verbose = 3)

# %%
grid.fit(scaled_train_df,y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END .................var_smoothing=0.1;, score=0.500 total time=   0.0s
# [CV 2/5] END .................var_smoothing=0.1;, score=0.357 total time=   0.0s
# [CV 3/5] END .................var_smoothing=0.1;, score=0.493 total time=   0.0s
# [CV 4/5] END .................var_smoothing=0.1;, score=0.371 total time=   0.0s
# [CV 5/5] END .................var_smoothing=0.1;, score=0.471 total time=   0.0s
# [CV 1/5] END ................var_smoothing=0.01;, score=0.429 total time=   0.0s
# [CV 2/5] END ................var_smoothing=0.01;, score=0.336 total time=   0.0s
# [CV 3/5] END ................var_smoothing=0.01;, score=0.457 total time=   0.0s
# [CV 4/5] END ................var_smoothing=0.01;, score=0.350 total time=   0.0s
# [CV 5/5] END ................var_smoothing=0.01;, score=0.379 total time=   0.0s
# [CV 1/5] END .................var_smoothing=0.5;, score=0.693 total time=   0.0s
# ...

# %%
grid.best_params_
# Out:
# {'var_smoothing': 0.5}

# %%
model_nb_new = GaussianNB(var_smoothing=0.5)
model_nb_new.fit(scaled_train_df, y_train)
y_pred_new = model_nb_new.predict(scaled_test_df)
print(accuracy_score(y_test, y_pred_new))
# Out:
# 0.7475083056478405

# %%
param_grid = {'n_estimators': [50,100,150,200],
             'max_depth' : range(3,11,1),
             'random_state' : [0,50,100,],
             'criterion' : ['gini','entropy']}

# %%
grid2 = GridSearchCV(model_rf,param_grid = param_grid, cv = 5, verbose = 3)

# %%
grid2.fit(scaled_train_df,y_train)
# Out:
# Fitting 5 folds for each of 192 candidates, totalling 960 fits
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=0;, score=0.764 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=0;, score=0.779 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=0;, score=0.771 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=0;, score=0.786 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=0;, score=0.779 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=50;, score=0.757 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=50;, score=0.771 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=3, n_estimators=50, random_state=50;, score=0.764 total time=   0.1s
# ...

# %%
grid2.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 9,
#  'n_estimators': 50,
#  'random_state': 100}

# %%
model_rf_new = RandomForestClassifier(criterion = 'entropy',max_depth =  9,n_estimators =  50,random_state =100)
model_rf_new.fit(scaled_train_df, y_train)
y_pred_new = model_rf_new.predict(scaled_test_df)
print(accuracy_score(y_pred_new,y_test))
# Out:
# 0.8073089700996677

# %%
import pickle

# %%
pickle.dump(model_rf_new, open('model.pkl','wb'))

# %%
pickle.dump(scaler,open('scaled.pkl','wb'))
